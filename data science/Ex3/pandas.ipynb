# %%
import numpy as np
import pandas as pd

df_drinks = pd.read_csv("drinks.csv")
df_cars1 = pd.read_csv("cars1.csv")
df_cars2 = pd.read_csv("cars2.csv")

# %%
# Question 1,Section 1

df_drinks.groupby('continent').mean()['beer_servings']
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
# Question 1,Section 2

df_drinks.groupby('continent').describe()['wine_servings']
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
# Question 1,Section 3

df_drinks.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
# Question 1,Section 4

df_drinks.groupby('continent').median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %%
# Question 1,Section 5

print("the mean amount of pure alcohol is: ", df_drinks['total_litres_of_pure_alcohol'].mean())
print("the minimum amount of pure alcohol is: ", df_drinks['total_litres_of_pure_alcohol'].min())
print("the maximum amount of pure alcohol is: ", df_drinks['total_litres_of_pure_alcohol'].max())
# Out:
# the mean amount of pure alcohol is:  4.717098445595855
# the minimum amount of pure alcohol is:  0.0
# the maximum amount of pure alcohol is:  14.4

# %%
# Question 2,Section 1

df_cars1 = df_cars1.drop(columns = ['Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'])
df_cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...

# %%
# Question 2,Section 2

print("in car1.csv there are {} entries and {} features".format(df_cars1.shape[0], df_cars1.shape[1]))
print("in car2.csv there are {} entries and {} features".format(df_cars2.shape[0], df_cars2.shape[1]))
# Out:
# in car1.csv there are 198 entries and 9 features
# in car2.csv there are 200 entries and 9 features

# %%
# Question 2,Section 3

df_cars1_contact_cars2 =  pd.concat([df_cars1, df_cars2], axis=1)
df_cars1_contact_cars2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0        8.0         307.0        130  3504.0          12.0   70.0
# 1    15.0        8.0         350.0        165  3693.0          11.5   70.0
# 2    18.0        8.0         318.0        150  3436.0          11.0   70.0
# 3    16.0        8.0         304.0        150  3433.0          12.0   70.0
# 4    17.0        8.0         302.0        140  3449.0          10.5   70.0
# 5    15.0        8.0         429.0        198  4341.0          10.0   70.0
# 6    14.0        8.0         454.0        220  4354.0           9.0   70.0
# 7    14.0        8.0         440.0        215  4312.0           8.5   70.0
# 8    14.0        8.0         455.0        225  4425.0          10.0   70.0
# 9    15.0        8.0         390.0        190  3850.0           8.5   70.0
# 10   15.0        8.0         383.0        170  3563.0          10.0   70.0
# ...

# %%
# Question 2,Section 4

random_list = []
rows_number = df_cars1_contact_cars2.shape[0]
for i in range(rows_number):
    random_number = np.random.randint(15000, 73000)
    random_list.append(random_number)
df_cars1_contact_cars2['owners'] = random_list
df_cars1_contact_cars2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0        8.0         307.0        130  3504.0          12.0   70.0
# 1    15.0        8.0         350.0        165  3693.0          11.5   70.0
# 2    18.0        8.0         318.0        150  3436.0          11.0   70.0
# 3    16.0        8.0         304.0        150  3433.0          12.0   70.0
# 4    17.0        8.0         302.0        140  3449.0          10.5   70.0
# 5    15.0        8.0         429.0        198  4341.0          10.0   70.0
# 6    14.0        8.0         454.0        220  4354.0           9.0   70.0
# 7    14.0        8.0         440.0        215  4312.0           8.5   70.0
# 8    14.0        8.0         455.0        225  4425.0          10.0   70.0
# 9    15.0        8.0         390.0        190  3850.0           8.5   70.0
# 10   15.0        8.0         383.0        170  3563.0          10.0   70.0
# ...

# %%
# Question 3,Section 1

raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}
df_data_1 = pd.DataFrame(raw_data_1) 

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}
df_data_2 = pd.DataFrame(raw_data_2)

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}
df_data_3 = pd.DataFrame(raw_data_3)

# %%
# Question 3,Section 2

df_data_1_contact_df_data_2 = pd.concat([df_data_1, df_data_2])
df_data_1_contact_df_data_2
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
# Question 3,Section 3

pd.merge(df_data_3, df_data_1_contact_df_data_2, on='subject_id')
# Out:
#   subject_id  test_id first_name last_name
# 0          1       51       Alex  Anderson
# 1          2       15        Amy  Ackerman
# 2          3       15      Allen       Ali
# 3          4       61      Alice      Aoni
# 4          4       61      Billy    Bonder
# 5          5       16     Ayoung   Atiches
# 6          5       16      Brian     Black
# 7          7       14      Bryce     Brice
# 8          8       15      Betty    Btisan

# %%
# Question 3,Section 4

pd.merge(df_data_1, df_data_2, how='inner', on='subject_id')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %%
# Question 3,Section 5

pd.merge(df_data_1, df_data_2, how='outer', on='subject_id')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %%
# Question 4,Section 1
   
animal_data = {
        'animal': ['Dog', 'Cat', 'Snake', 'Snake', 'Dog', 'Hamster', 'Cat', 'Alligator', 'Cat', 'Cat', 'Dog', 'Hamster', 'Alligator'],
        'age': [10, 11, 9, 2, 7, 3, 16, 45, 4.5, 9.1, 1, 1.6, 50], 
        'weight': [5.3, 4.5, 95, 33, 20, 0.036, 7.36, 254.5, 8, 4.12, 23.2, 0.024, 278],
        'length': [104.2, 78, 24.8, 240.97, 38.41, 10.45, 45.6, 350.5, 71.69, 63.36, 38.1, 10.48, 222.44]}
df_animal = pd.DataFrame(animal_data)
df_animal
# Out:
#        animal   age   weight  length
# 0         Dog  10.0    5.300  104.20
# 1         Cat  11.0    4.500   78.00
# 2       Snake   9.0   95.000   24.80
# 3       Snake   2.0   33.000  240.97
# 4         Dog   7.0   20.000   38.41
# 5     Hamster   3.0    0.036   10.45
# 6         Cat  16.0    7.360   45.60
# 7   Alligator  45.0  254.500  350.50
# 8         Cat   4.5    8.000   71.69
# 9         Cat   9.1    4.120   63.36
# 10        Dog   1.0   23.200   38.10
# 11    Hamster   1.6    0.024   10.48
# 12  Alligator  50.0  278.000  222.44

# %%
# Question 4,Section 2

animal_groups = df_animal.sort_values(by=['animal'])
animal_groups
# Out:
#        animal   age   weight  length
# 7   Alligator  45.0  254.500  350.50
# 12  Alligator  50.0  278.000  222.44
# 1         Cat  11.0    4.500   78.00
# 6         Cat  16.0    7.360   45.60
# 8         Cat   4.5    8.000   71.69
# 9         Cat   9.1    4.120   63.36
# 0         Dog  10.0    5.300  104.20
# 4         Dog   7.0   20.000   38.41
# 10        Dog   1.0   23.200   38.10
# 5     Hamster   3.0    0.036   10.45
# 11    Hamster   1.6    0.024   10.48
# 2       Snake   9.0   95.000   24.80
# 3       Snake   2.0   33.000  240.97

# %%
# Question 4,Section 3

animal_groups.groupby('animal').mean().loc['Cat', 'weight']
# Out:
# 5.995

# %%
# Question 4,Section 4

animal_groups.groupby('animal').max().loc['Cat', 'age']
# Out:
# 16.0

# %%
# Question 4,Section 5

animal_groups['animal'].value_counts()
# Out:
# Cat          4
# Dog          3
# Snake        2
# Hamster      2
# Alligator    2
# Name: animal, dtype: int64

# %%
# Question 4,Section 6

animal_groups['length'].median()
# Out:
# 63.36
