# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
mew = 100
sigma = 15
fig, ax = plt.subplots()
ax.set_title("IQ Score Distribution")
ax.set_ylabel("% Population")
ax.set_xlabel("IQ score")
x = np.random.normal(mew,sigma,10**6)
ix = sns.kdeplot(x, shade=False)
l1 = ix.lines[0]
x1 = l1.get_xydata()[:,0]
y1 = l1.get_xydata()[:,1]
sns.lineplot([x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
             [y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
plt.text(x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "65%",  color="#abdcef")
sns.lineplot([x1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
             [y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
plt.text(x1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "96%",  color="#abdcef")
sns.lineplot([x1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
             [y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
plt.text(x1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "99%",  color="#abdcef")
points = len(x1)
ix.fill_between(x1,y1, color="#bb84f0")
ix.fill_between(x1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])],
                y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], color="#b5ac00")
ix.fill_between(x1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])],
                y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], color="#133d00")
ix.fill_between(x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])],
                y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])], color="#000000")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d5e481064d8e> in <module>
#      10 x1 = l1.get_xydata()[:,0]
#      11 y1 = l1.get_xydata()[:,1]
# ---> 12 sns.lineplot([x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
#      13              [y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
#      14 plt.text(x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "65%",  color="#abdcef")
#
# NameError: name 'points' is not defined

# %%
mew = 100
sigma = 22
fig, ax = plt.subplots()
ax.set_title("IQ Score Distribution")
ax.set_ylabel("% Population")
ax.set_xlabel("IQ score")
x = np.random.normal(mew,sigma,10**6)
ix = sns.kdeplot(x, shade=False)
l1 = ix.lines[0]
x1 = l1.get_xydata()[:,0]
y1 = l1.get_xydata()[:,1]
sns.lineplot([x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
             [y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
plt.text(x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "65%",  color="#abdcef")
sns.lineplot([x1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
             [y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
plt.text(x1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "96%",  color="#abdcef")
sns.lineplot([x1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
             [y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
plt.text(x1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "99%",  color="#abdcef")
points = len(x1)
ix.fill_between(x1,y1, color="#bb84f0")
ix.fill_between(x1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])],
                y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], color="#b5ac00")
ix.fill_between(x1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])],
                y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], color="#133d00")
ix.fill_between(x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])],
                y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])], color="#000000")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7d7cf9c92821> in <module>
#      10 x1 = l1.get_xydata()[:,0]
#      11 y1 = l1.get_xydata()[:,1]
# ---> 12 sns.lineplot([x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
#      13              [y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
#      14 plt.text(x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "65%",  color="#abdcef")
#
# NameError: name 'points' is not defined

# %%
mew = (100*6+115)/7
sigma = 15
fig, ax = plt.subplots()
ax.set_title("IQ Score Distribution")
ax.set_ylabel("% Population")
ax.set_xlabel("IQ score")
x = np.random.normal(mew,sigma,10**6)
ix = sns.kdeplot(x, shade=False)
l1 = ix.lines[0]
x1 = l1.get_xydata()[:,0]
y1 = l1.get_xydata()[:,1]
sns.lineplot([x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
             [y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
plt.text(x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "65%",  color="#abdcef")
sns.lineplot([x1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
             [y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
plt.text(x1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "96%",  color="#abdcef")
sns.lineplot([x1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
             [y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
plt.text(x1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "99%",  color="#abdcef")
points = len(x1)
ix.fill_between(x1,y1, color="#bb84f0")
ix.fill_between(x1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])],
                y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], color="#b5ac00")
ix.fill_between(x1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])],
                y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], color="#133d00")
ix.fill_between(x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])],
                y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])], color="#000000")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-48e88bec4fa4> in <module>
#      10 x1 = l1.get_xydata()[:,0]
#      11 y1 = l1.get_xydata()[:,1]
# ---> 12 sns.lineplot([x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
#      13              [y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
#      14 plt.text(x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "65%",  color="#abdcef")
#
# NameError: name 'points' is not defined

# %%
mew = 100
sigma = 15
fig, ax = plt.subplots()
ax.set_title("IQ Score Distribution")
ax.set_ylabel("% Population")
ax.set_xlabel("IQ score")
x = np.random.normal(mew,sigma,10**6)
# ix = sns.distplot(x, kde=False)
# l1 = ix.lines[0]
# x1 = l1.get_xydata()[:,0]
# y1 = l1.get_xydata()[:,1]
# sns.lineplot([x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
#              [y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
# plt.text(x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "65%",  color="#abdcef")
# sns.lineplot([x1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
#              [y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
# plt.text(x1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "96%",  color="#abdcef")
# sns.lineplot([x1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], x1[int((mew+3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]],
#              [y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])]], color="#ffffff")
# plt.text(x1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], "99%",  color="#abdcef")
# points = len(x1)
# ix.fill_between(x1,y1, color="#bb84f0")
# ix.fill_between(x1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])],
#                 y1[int((mew-3*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+3*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], color="#b5ac00")
# ix.fill_between(x1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])],
#                 y1[int((mew-2*sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+2*sigma-x1[0])*points)//int(x1[points-1]-x1[0])], color="#133d00")
# ix.fill_between(x1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])],
#                 y1[int((mew-sigma-x1[0])*points)//int(x1[points-1]-x1[0]):int((mew+sigma-x1[0])*points)//int(x1[points-1]-x1[0])], color="#000000")
plt.hist(x, range(int(min(x)), int(max(x))), color="#000000")
y, bins, bars = plt.hist(x, range(mew-3*sigma, mew+3*sigma), color="red")
ax = sns.lineplot([mew-3*sigma,mew+3*sigma], [y[0] ,y[0]], color='black')
plt.text(mew, y[0], "99%",  color="#000000")
y, bins, bars = plt.hist(x, range(mew-2*sigma, mew+2*sigma), color="yellow")
plt.text(mew, y[0], "96%",  color="#000000")
ax = sns.lineplot([mew-2*sigma,mew+2*sigma], [y[0] ,y[0]], color='black')
y, bins, bars = plt.hist(x, range(mew-sigma, mew+sigma), color="blue")
plt.text(mew, y[0], "65%",  color="#000000")
ax = sns.lineplot([mew-sigma,mew+sigma], [y[0] ,y[0]], color='black')
